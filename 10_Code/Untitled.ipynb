# %%
import pandas as pd
import numpy as np

# %%
dfM = pd.read_csv('MigrationPerCountry_Top10_v04.csv', sep = ',')

# %%
dfM.head()
# Out:
#          Country        Type    Coverage          OdName  Year  Migrants  \
# 0        Germany  Immigrants        Both          Turkey  1980    213126
# 1        Germany  Immigrants        Both           Italy  1980     88865
# 2        Germany  Immigrants        Both          Poland  1980     67940
# 3  United States  Immigrants  Foreigners          Mexico  1980     56680
# 4      Australia  Immigrants        Both  United Kingdom  1980     43540
#
#                          Flow       dLat     dLong       oLat       oLong ID
# 0            Turkey - Germany  51.500000   10.5000  39.059012   34.911546  a
# 1             Italy - Germany  51.500000   10.5000  42.833333   12.833333  b
# 2            Poland - Germany  51.500000   10.5000  52.000000   20.000000  c
# 3      Mexico - United States  39.828175  -98.5795  23.000000 -102.000000  d
# 4  United Kingdom - Australia -25.000000  135.0000  54.000000   -4.000000  e

# %%
# %%timeit -o
dfM['dLat'].tail(7)
# Out:
# The slowest run took 6.32 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 40.6 µs per loop
# <TimeitResult : 10000 loops, best of 3: 40.6 µs per loop>

# %%
# %%timeit -o
dfM['dLat'].tail(7).mean()
# Out:
# The slowest run took 59.40 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 79 µs per loop
# <TimeitResult : 10000 loops, best of 3: 79 µs per loop>

# %%
# %%timeit -o
np.mean(dfM['dLat'].tail(7))
# Out:
# The slowest run took 9.38 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 82.2 µs per loop
# <TimeitResult : 10000 loops, best of 3: 82.2 µs per loop>

# %%
# %%timeit -o
dfM['dLat'][-7:]
# Out:
# The slowest run took 18.36 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 53.3 µs per loop
# <TimeitResult : 10000 loops, best of 3: 53.3 µs per loop>

# %%
# %%timeit -o
dfM['dLat'][-7:].mean()
# Out:
# 10000 loops, best of 3: 92.7 µs per loop
# <TimeitResult : 10000 loops, best of 3: 92.7 µs per loop>

# %%
# %%timeit -o
np.mean(dfM['dLat'][-7:])
# Out:
# The slowest run took 7.70 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 99.6 µs per loop
# <TimeitResult : 10000 loops, best of 3: 99.6 µs per loop>

# %%
dfM['Year'].unique()
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013], dtype=int64)

# %%
for i in np.sort(dfM['Year'].unique())[::-1]:
    print i
# Out:
# 2013
# 2012
# 2011
# 2010
# 2009
# 2008
# 2007
# 2006
# 2005
# 2004
# 2003
# 2002
# 2001
# 2000
# 1999
# 1998
# 1997
# 1996
# 1995
# 1994
# 1993
# 1992
# 1991
# 1990
# 1989
# 1988
# 1987
# 1986
# 1985
# 1984
# 1983
# 1982
# 1981
# 1980

# %%
n_minDaysShift = None

# %%
~(n_minDaysShift is None)
# Out:
# -2

# %%
n_minDaysShift is None
# Out:
# True

# %%
if ~(n_minDaysShift is None):
    print 's'
# Out:
# s

# %%
~True
# Out:
# -2

# %%
not(True)
# Out:
# False

# %%
dfM[~(dfM['Year'] == 1980)]
# Out:
#             Country        Type    Coverage              OdName  Year  \
# 10          Germany  Immigrants        Both              Poland  1981
# 11    United States  Immigrants  Foreigners              Mexico  1981
# 12          Germany  Immigrants        Both              Turkey  1981
# 13          Germany  Immigrants        Both               Italy  1981
# 14        Australia  Immigrants        Both      United Kingdom  1981
# 15    United States  Immigrants  Foreigners             Vietnam  1981
# 16    United States  Immigrants  Foreigners         Philippines  1981
# 17            Italy  Immigrants        Both         Switzerland  1981
# 18        Australia  Immigrants        Both         New Zealand  1981
# 19    United States  Immigrants  Foreigners         Korea, Rep.  1981
# 20    United States  Immigrants  Foreigners             Vietnam  1982
# 21          Germany  Immigrants        Both              Poland  1982
# ...

# %%
(dfM['Year'] == 1980)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 310    False
# 311    False
# 312    False
# 313    False
# 314    False
# 315    False
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# 321    False
# 322    False
# 323    False
# 324    False
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# 334    False
# 335    False
# 336    False
# 337    False
# 338    False
# 339    False
# Name: Year, dtype: bool

# %%
~(dfM['Year'] == 1980)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 310     True
# 311     True
# 312     True
# 313     True
# 314     True
# 315     True
# 316     True
# 317     True
# 318     True
# 319     True
# 320     True
# 321     True
# 322     True
# 323     True
# 324     True
# 325     True
# 326     True
# 327     True
# 328     True
# 329     True
# 330     True
# 331     True
# 332     True
# 333     True
# 334     True
# 335     True
# 336     True
# 337     True
# 338     True
# 339     True
# Name: Year, dtype: bool
